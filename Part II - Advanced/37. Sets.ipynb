# %% [markdown]
# ## 1: Introduction to Sets
# 1. What are Sets?
# 2. Set Properties and Characteristics
# 3. Set Operations and Manipulations
#
# ## 2: Creating Sets
# 1. Creating Sets using Set Literals
# 2. Creating Sets from Iterables
# 3. Creating Empty Sets
#
# ## 3: Set Operations
# 1. Adding Elements to a Set
# 2. Removing Elements from a Set
# 3. Checking Membership in a Set
# 4. Set Union and Intersection
# 5. Set Difference and Symmetric Difference
# 6. Subset, Superset, and Disjoint Sets
#
# ## 4: Modifying Sets
# 1. Updating a Set with Another Set
# 2. Removing Elements from a Set
# 3. Clearing a Set
#
# ## 5: Set Methods and Functions
# 1. Set Size and Cardinality
# 2. Set Equality and Comparisons
# 3. Set Iteration and Conversion
# 4. Set Copying and Cloning
#
# ## 6: Set Comprehensions
# 1. Creating Sets using Comprehensions
# 2. Filtering Elements in Set Comprehensions
# 3. Nested Set Comprehensions
#
# ## 7: Set Applications and Use Cases
# 1. Removing Duplicates from a List using Sets
# 2. Testing Membership and Finding Common Elements
# 3. Set Operations in Data Analysis and Set Theory
#
# ## 8: Immutable Sets (frozensets)
# 1. Creating and Using Immutable Sets
# 2. Immutable Set Operations
#
# ## 9: Set Performance and Efficiency
# 1. Set Operations Complexity
# 2. Choosing the Right Data Structure for the Problem
#
# ## 10: Set Operations with Other Data Types
# 1. Sets and Lists
# 2. Sets and Tuples
# 3. Sets and Dictionaries
#
# ## 11: Set Best Practices and Tips
# 1. Proper Set Usage and Avoiding Common Pitfalls
# 2. Memory Management and Set Size Considerations
#
# ## 12: Conclusion and Further Resources
# 1. Recap of Set Concepts and Operations
# 2. Additional Resources for Learning and Exploring Sets
